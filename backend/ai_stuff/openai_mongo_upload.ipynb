# %%
import openai
import json
from pymongo import MongoClient

# %%
with open('articles_metadata.json', 'r') as file:
    articles = json.load(file)
with open("secrets.json", 'r') as f:
    secrets = json.load(f)

# %%
openai.api_key = secrets["openai_key"]

# %%
# Preprocessing
to_embed = [json.dumps({
    "title": article["title"],
    "description": article["description"],
    "doc_type": article["doc_type"]
    })for article in articles]

# %%
response = openai.embeddings.create(
    model="text-embedding-3-small",
    input=to_embed
)

# %%
embedding_vectors = [point.embedding for point in response.data]

# %%
len(embedding_vectors)
# Out:
# 496

# %%
secrets["mongo_uri"]
# Out:
# 'mongodb+srv://pranavshridhar0:33dBTU3TIsFf0hwK@nasahack.ghumh.mongodb.net/?retryWrites=true&w=majority&appName=NASAHack'

# %%
import certifi
uri = secrets["mongo_uri"]

client = MongoClient(uri, tlsCAFile=certifi.where())
db = client["nasa"]
collection = db["article_collection"]

# %%
to_upload = [{
    "title": article["title"],
    "description": article["description"],
    "doc_type": article["doc_type"],
    "url": article["url"]
    } for article in articles]
to_upload
# Out:
# [{'title': 'A Beginning Look at Photosynthesis',
#   'description': 'Students learn about plant response to light by setting up simple investigations in the classroom.',
#   'doc_type': 'Learning Activities',
#   'url': 'https://www.globe.gov/documents/355050/4a998d4a-4001-4573-bf13-6bda6e0b0b37'},
#  {'title': 'A Field View of Soil - Digging Around',
#   'description': 'Students discover that soil properties such as moisture and temperature can vary considerably across a single landscape.',
#   'doc_type': 'Learning Activities',
#   'url': 'https://www.globe.gov/documents/352961/a744ce39-0be0-4e30-999b-ad2fb8b0be94'},
#  {'title': 'A SneakPreview of Budburst',
#   'description': 'Students learn what to look for during budburst by observing variations in timing and appearance of leaves of different local plant species.',
#   'doc_type': 'Learning Activities',
#   'url': 'https://www.globe.gov/documents/355050/5fa93edf-852a-43f0-8ef9-44300e5a2fc6'},
# ...

# %%
for doc, vector in zip(to_upload, embedding_vectors):
    doc["vector"] = vector  # Add the vector to the corresponding dictionary

# %%
collection.insert_many(to_upload)
# Out:
# InsertManyResult([ObjectId('6702c1fe9a429380abde7368'), ObjectId('6702c1fe9a429380abde7369'), ObjectId('6702c1fe9a429380abde736a'), ObjectId('6702c1fe9a429380abde736b'), ObjectId('6702c1fe9a429380abde736c'), ObjectId('6702c1fe9a429380abde736d'), ObjectId('6702c1fe9a429380abde736e'), ObjectId('6702c1fe9a429380abde736f'), ObjectId('6702c1fe9a429380abde7370'), ObjectId('6702c1fe9a429380abde7371'), ObjectId('6702c1fe9a429380abde7372'), ObjectId('6702c1fe9a429380abde7373'), ObjectId('6702c1fe9a429380abde7374'), ObjectId('6702c1fe9a429380abde7375'), ObjectId('6702c1fe9a429380abde7376'), ObjectId('6702c1fe9a429380abde7377'), ObjectId('6702c1fe9a429380abde7378'), ObjectId('6702c1fe9a429380abde7379'), ObjectId('6702c1fe9a429380abde737a'), ObjectId('6702c1fe9a429380abde737b'), ObjectId('6702c1fe9a429380abde737c'), ObjectId('6702c1fe9a429380abde737d'), ObjectId('6702c1fe9a429380abde737e'), ObjectId('6702c1fe9a429380abde737f'), ObjectId('6702c1fe9a429380abde7380'), ObjectId('6702c1fe9a429380abde
# ...
